# %% [markdown]
# # Syncraft Dev Mode Demo
#
# This notebook demonstrates how to use Syncraft's development features for grammar visualization, AST visualization, and rich debugging.

# %% [markdown]
# ## 1. Install Dev Dependencies
#
# If you have not already installed the dev dependencies, run:
#
# ```
# ,
# ,
# ,
#
# :
# ,
# : {
# :
# },
# : [
# 2
#
# :
# ,
# : {
# :
# },
# : [
# ,
# ,
# ,
# ,
# ,
# ,
#
# :
# ,
# : {
# :
# },
# : [
# 3
#
# :
# ,
# : {
# :
# },
# : [
# ,
# ,
# ,
#
# :
# ,
# : {
# :
# },
# : [
# 4
#
# :
# ,
# : {
# :
# },
# : [
# ,
# ,
# ,
# ,
# ,
# ,
