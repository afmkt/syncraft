# %% [markdown]
# # Syncraft Notebook Test Example
# This notebook demonstrates a simple testable workflow for Syncraft using nbval and pytest.

# %%
# Import a Syncraft module
from syncraft import algebra

# %% [markdown]
# ## Test a simple algebra operation
# Below, we test that algebra.compose returns a function.
