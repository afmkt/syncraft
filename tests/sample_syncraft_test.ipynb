# %% [markdown]
# # Visualizing Syncraft Syntax and AST
# This quick notebook shows how to use the helper utilities in `syncraft/dev.py` to inspect grammar definitions (`Syntax`) and the abstract syntax trees (AST) they produce. The helpers work both in plain text and as SVG diagrams for richer visualisation.

# %% [markdown]
# ## Setup
# Import the helpers and choose a sample grammar. Feel free to swap in your own `Syntax` definitions.

# %%
# Import everything fresh
from syncraft.regex import Regex, parse
from syncraft.vis import syntax2svg, ast2svg
from IPython.display import SVG, display, HTML

# %%
ast_result = parse('ab*')
ast_result.vis(5)
# Out:
# SVGVisualization(<ns0:svg xmlns:ns0="http://www.w3.org/2000/svg" width="218pt" height="332pt" viewBox="0.00 0.00 218.00 332.00"><ns0:g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 328)"><ns0:polygon fill="white" stroke="none" points="-4,4 -4,-328 214.18,-328 214.18,4 -4,4" /><ns0:g id="node1" class="node"><ns0:title>n0</ns0:title><ns0:ellipse fill="none" stroke="black" cx="105.09" cy="-306" rx="67.22" ry="18" /><ns0:text xml:space="preserve" text-anchor="middle" x="105.09" y="-300.95" font-family="Times,serif" font-size="14.00">Collect(Regex)</ns0:text></ns0:g><ns0:g id="node2" class="node"><ns0:title>n1</ns0:title><ns0:ellipse fill="none" stroke="black" cx="105.09" cy="-234" rx="105.09" ry="18" /><ns0:text xml:space="preserve" text-anchor="middle" x="105.09" y="-228.95" font-family="Times,serif" font-size="14.00">Marked(name=branches)</ns0:text></ns0:g><ns0:g id="edge1" class="edge"><ns0:title>n0-&gt;n1</ns0:title><ns0:path fill="none" stroke="black" d="M105.09,-287.7C105.09,-280.41 105.09,-271.73 105.09,-263.54" /><ns0:polygon fill="black" stroke="black" points="108.59,-263.62 105.09,-253.62 101.59,-263.62 108.59,-263.62" /></ns0:g><ns0:g id="node3" class="node"><ns0:title>n2</ns0:title><ns0:ellipse fill="none" stroke="black" cx="105.09" cy="-162" rx="32.93" ry="18" /><ns0:text xml:space="preserve" text-anchor="middle" x="105.09" y="-156.95" font-family="Times,serif" font-size="14.00">Many</ns0:text></ns0:g><ns0:g id="edge2" class="edge"><ns0:title>n1-&gt;n2</ns0:title><ns0:path fill="none" stroke="black" d="M105.09,-215.7C105.09,-208.41 105.09,-199.73 105.09,-191.54" /><ns0:polygon fill="black" stroke="black" points="108.59,-191.62 105.09,-181.62 101.59,-191.62 108.59,-191.62" /></ns0:g><ns0:g id="node4" class="node"><ns0:title>n3</ns0:title><ns0:ellipse fill="none" stroke="black" cx="105.09" cy="-90" rx="70.29" ry="18" /><ns0:text xml:space="preserve" text-anchor="middle" x="105.09" y="-84.95" font-family="Times,serif" font-size="14.00">Collect(Branch)</ns0:text></ns0:g><ns0:g id="edge3" class="edge"><ns0:title>n2-&gt;n3</ns0:title><ns0:path fill="none" stroke="black" d="M105.09,-143.7C105.09,-136.41 105.09,-127.73 105.09,-119.54" /><ns0:polygon fill="black" stroke="black" points="108.59,-119.62 105.09,-109.62 101.59,-119.62 108.59,-119.62" /></ns0:g><ns0:g id="node5" class="node"><ns0:title>n4</ns0:title><ns0:ellipse fill="none" stroke="black" cx="105.09" cy="-18" rx="95.37" ry="18" /><ns0:text xml:space="preserve" text-anchor="middle" x="105.09" y="-12.95" font-family="Times,serif" font-size="14.00">Marked(name=pieces)</ns0:text></ns0:g><ns0:g id="edge4" class="edge"><ns0:title>n3-&gt;n4</ns0:title><ns0:path fill="none" stroke="black" d="M105.09,-71.7C105.09,-64.41 105.09,-55.73 105.09,-47.54" /><ns0:polygon fill="black" stroke="black" points="108.59,-47.62 105.09,-37.62 101.59,-47.62 108.59,-47.62" /></ns0:g></ns0:g></ns0:svg>)
